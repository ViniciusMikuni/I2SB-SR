# %%
import torch
import matplotlib.pyplot as plt
from PIL import Image
import h5py
import numpy as np
# !pip install cmocean
import cmocean
import yaml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
file_path = '/pscratch/sd/v/vmikuni/FM/results/test/image_1000.npz'

# %%
loaded_data = np.load(file_path)
dict_names = {
    'low_res': 'w Upscaled Low Resolution Image',
    'high_res': 'w Original High Resolution Image',
    'super_res': 'w Super Resolution Image',
}

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
for i, name in enumerate(dict_names):
    axs[i].imshow(loaded_data[name][1,2],cmap=cmocean.cm.balance)
    axs[i].set_title(dict_names[name])
    axs[i].axis('off')
